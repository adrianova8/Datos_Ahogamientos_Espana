# %% [markdown]
# ![UIMP.jpeg](attachment:UIMP.jpeg)

# %% [markdown]
# <div class="alert alert-block alert-info"><font size="5"><center><b><u>Adrià Nova Pagés</u></b></center></font>

# %% [markdown]
# # <span style=color:darkblue> Datos de Ahogamiento con Datos Meteorológicos - Series Temporales</span>
#
#
#  **DESCRIPCIÓN DE LAS VARIABLES**
# - **Fecha:** Esta variable representa la fecha en la que ocurrió el accidente acuático y se compone de tres partes: el día, el mes y el año. Es una variable temporal que permite identificar el momento en que ocurrió el incidente.
# ---
# - **IdAhogado:** Es un identificador único asignado a cada incidente de ahogamiento registrado en el conjunto de datos. Esta variable ayuda a distinguir cada incidente de ahogamiento registrado y a realizar análisis específicos para cada caso.
# ---
# - **IdPersona:** Es un identificador único asignado a cada persona involucrada en un incidente de ahogamiento. Esta variable permite distinguir cada persona involucrada en el incidente y llevar a cabo análisis específicos para cada caso.
# ---
# - **Localidad:** Es el nombre de la ciudad o pueblo donde se produjo el accidente acuático. Esta variable indica la ubicación geográfica del incidente y permite realizar análisis geográficos y comparar los incidentes en diferentes lugares.
# ---
# - **Provincia:** Es la demarcación administrativa dentro del país donde se produjo el accidente acuático. Esta variable ayuda a realizar análisis a nivel regional y comparar los incidentes entre diferentes provincias.
# ---
# - **Comunidad Autónoma (CCAA):** Es la entidad territorial dotada de autonomía dentro del actual ordenamiento jurídico constitucional, donde se produjo el accidente acuático. Esta variable permite realizar análisis a nivel regional y comparar los incidentes entre diferentes comunidades autónomas.
# ---
# - **Hora:** Esta variable indica la hora en la que ocurrió el accidente acuático y se expresa en horas y minutos. Es una variable temporal que permite identificar la hora del día en que se produjo el incidente.
# ---
# - **Latitud:** Es la distancia en grados, minutos y segundos con respecto al paralelo principal, que es el ecuador (0º). Esta variable indica la ubicación geográfica del incidente en el hemisferio norte o sur.
# ---
# - **Longitud:** Es la distancia en grados, minutos y segundos con respecto al meridiano principal, que es el meridiano de Greenwich (0º). Esta variable indica la ubicación geográfica del incidente en el este o oeste del meridiano principal.
# ---
# - **Sexo:** Esta variable indica el género de la persona involucrada en el incidente de ahogamiento. Toma el valor de "M" si es masculino y "F" si es femenino.
# ---
# - **Edad:** Esta variable indica la edad de la persona involucrada en el incidente de ahogamiento. Es una variable numérica que permite realizar análisis sobre la edad de los afectados.
# ---
# - **Nacionalidad:** Esta variable indica la nación o territorio en el que vive la persona involucrada en el incidente de ahogamiento. Permite realizar análisis sobre los incidentes que involucran a personas de diferentes nacionalidades.
# ---
# - **Origen:** Esta variable indica si la persona involucrada en el incidente de ahogamiento era local, extranjera, residente, limítrofe o de otra comunidad autónoma. Permite realizar análisis sobre la procedencia de los afectados.
# ---
# - **Titular:** El titular se refiere al encabezado de la noticia que busca captar la atención de los lectores y resumir el contenido de la misma.
# ---
# - **Causa:** Esta variable se refiere a las circunstancias que llevaron al individuo a sufrir un accidente acuático, como pueden ser errores de juicio, falta de habilidad para nadar, la presencia de obstáculos o peligros en el agua, entre otros factores.
# ---
# - **TipoAhogamiento:** El tipo de ahogamiento hace referencia a la forma en que el individuo se ahogó, como puede ser por sumersión, aspiración de agua, hipotermia, entre otras causas.
# ---
# - **Factor:** Los factores se refieren a las condiciones o situaciones que aumentan la probabilidad de que un individuo sufra un accidente acuático, como pueden ser la falta de conocimiento o formación en natación, la ausencia de medidas de seguridad adecuadas, entre otros.
# ---
# - **Intervención:** La intervención hace referencia a las acciones que se llevaron a cabo tras el accidente acuático para asistir al individuo, como pueden ser la aplicación de primeros auxilios, la llamada a servicios de emergencia, entre otros.
# ---
# - **Pronóstico:** El pronóstico se refiere a la predicción de la evolución del individuo tras sufrir el accidente acuático, como puede ser su recuperación, secuelas o incluso fallecimiento.
# ---
# - **Localización:** La localización se refiere al lugar donde fue encontrado el individuo que sufrió el accidente acuático, como puede ser una piscina, un río, el mar, entre otros.
# ---
# - **Riesgo:** El riesgo hace referencia a las condiciones del agua para poder realizar actividades acuáticas, considerando banderas rojas, amarillas o verdes, que indican el nivel de peligro y seguridad para los bañistas.
# ---
# - **Reanimación:** La reanimación se refiere al tipo de técnicas de primeros auxilios que se utilizaron para intentar revivir al individuo tras sufrir el accidente acuático, como pueden ser la respiración boca a boca o la aplicación de desfibriladores automáticos externos.
# ---
# - **Vigilancia:** La vigilancia se refiere a si había presencia de personal especializado en el momento de producirse el accidente acuático, como pueden ser socorristas, bomberos o personal médico.
# ---
# - **Actividad:** La actividad se refiere a la acción que estaba realizando el individuo en el momento de sufrir el accidente acuático, como pueden ser nadar, bucear, pescar, entre otras.
# ---
# - **Detección:** La detección se refiere a quién fue el primero en notar o darse cuenta del accidente acuático, como pueden ser testigos presenciales, familiares o amigos del individuo, entre otros.
# ---
# - **Enlace1:** Enlace1 se refiere al titular de noticia en la que se confirma el accidente acuático.
# ---
# - **Indicador:** El indicador se refiere al número asociado que se le otorga a cada estación meteorológica.
# ---
# - **Estacion:** Estación se refiere al nombre que recibe la estación meteorológica por provincia.
# ---
# - **Altitud:** La altitud se refiere la ditancia entre un punto de la superfície terrestre respecto el nivel del mar en el que se produjó el accidente acuático.
# ---
# - **TempMed:** La temperatura media se refiere a la temperatura que hizo a lo largo del dia, de media, en que se produjo el accidente acuático.
# ---
# - **Precip:** La precipitación se refiere a la cantidad de litros por m2 que hubo en el dia del accidente acuático (l/m2).
# ---
# - **TempMin:** La temperatura mínima se refiere a la temperatura más baja que se registro a lo largo del dia en que se produjo el accidente acuático.
# ---
# - **TempMax:** La temperatura máxima se refiere a la temperatura más alta que se registro a lo largo del dia en que se produjo el accidente acuático.
# ---
# - **DirViento:** La direccion del viento se refiere en la dirección en la que sopla el viento, ya sea norte, sur, este u oeste en el momento del accidente acuático.
# ---
# - **VelMedViento:** La velocidad media del viento se refiere a la velocidad que se registro a lo largo del dia, de media, en que se produjo el accidente acuático en metros por segundo(m/s).
# ---
# - **RachaViento:** La racha de viento se refiere al aumento repentino del viento que excede el viento promedio de 18km/h para el dia en que se registró el accidente acuático.
# ---
# - **TiempoSol:** El tiempo de sol se refiere al número de horas que tuvo el dia del accidente acuático.
# ---
# - **PresionMax:** La presión máxima se refiere a la fuerza máxima que ejerce el aire sobre la superfície terrestre, cuantos más accidentes acuáticos cerca del mar mayor presión.
# ---
# - **PresionMin:** La presión mínima se refiere a la fuerza mínima que ejerce el aire sobre la superfície terrestre, cuantos menos accidentes acuáticos cerca del mar menor presión.

# %% [markdown]
# **REFERENCIAS**
# - https://www.machinelearningplus.com/time-series/time-series-analysis-python/?utm_content=cmp-true
# - https://www.machinelearningplus.com/time-series/arima-model-time-series-forecasting-python/

# %%
# Librerias 
import numpy as np
import pandas as pd
import calendar
import matplotlib.pyplot as plt
import plotly.express as px
from dateutil.parser import parse
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima.arima.utils import ndiffs
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import pmdarima as pm
import seaborn as sns

# %%
# Cargamos los datos
#pd.set_option('display.max_columns', None)
datos_ahogamientos = pd.read_csv("/Users/adrianova/Desktop/git/TFM - Notebooks/datos_ahogamiento_meteorologicos.csv", parse_dates=['Fecha'], dayfirst=True)
datos_ahogamientos.head()
# Out:
#        Fecha  IdAhogado  IdPersona                            Localidad  \
# 0 2020-12-30       7432       8532                        Torredembarra
# 1 2020-12-29       7431       8531  Cádiz, Playa de Santa Maria del Mar
# 2 2020-12-29       7426       8525            San Sebastián, Río Urumea
# 3 2020-12-29       7426       8526            San Sebastián, Río Urumea
# 4 2020-12-28       7427       8527                          La Graciosa
#
#     Provincia        CCAA   Hora    Latitud    Longitud    Sexo  ...  TempMed  \
# 0   Tarragona    Cataluña    NaN  41.130523    1.395311     NaN  ...     10.0
# 1       Cádiz   Andalucía  17:48  36.519991   -6.287258     NaN  ...     12.2
# 2   Guipúzcoa  País Vasco  02:30  43.317215   -1.977996  Hombre  ...      5.4
# 3   Guipúzcoa  País Vasco  02:30  43.317215   -1.977996  Hombre  ...      5.4
# 4  Las Palmas    Canarias  07:30  29.225448  -13.502007  Hombre  ...     19.6
#
# ...

# %%
# Shape
datos_ahogamientos.shape
# Out:
# (8015, 40)

# %%
# Creamos un dataframe que solo tenga en cuenta la Fecha y el número de ahogamientos
ahogamientos_fecha = datos_ahogamientos['Fecha'].value_counts()
ahogamientos_fecha = pd.DataFrame(ahogamientos_fecha.rename('Ahogamientos'))
ahogamientos_fecha.head()
# Out:
#             Ahogamientos
# 2013-07-30            44
# 2020-07-18            31
# 2016-04-19            28
# 2020-08-05            26
# 2020-08-08            25

# %%
# Desglosamos la variable fecha por dia, mes y año
ahogamientos_fecha = ahogamientos_fecha.reset_index()

ahogamientos_fecha['Dia'] = ahogamientos_fecha['index'].dt.day
ahogamientos_fecha['Mes'] = ahogamientos_fecha['index'].dt.month
ahogamientos_fecha['Anio'] = ahogamientos_fecha['index'].dt.year

ahogamientos_fecha.head()
# Out:
#        index  Ahogamientos  Dia  Mes  Anio
# 0 2013-07-30            44   30    7  2013
# 1 2020-07-18            31   18    7  2020
# 2 2016-04-19            28   19    4  2016
# 3 2020-08-05            26    5    8  2020
# 4 2020-08-08            25    8    8  2020

# %%
# Cambiar el nombre de la columna "index" a "Fecha"
ahogamientos_fecha = ahogamientos_fecha.rename(columns={'index': 'Fecha'})

# Realizando cambios en la base de datos
ahogamientos_fecha = ahogamientos_fecha.reindex(columns=['Fecha', 'Dia', 'Mes', 'Anio', 'Ahogamientos'])

# Ordenamos los datos por Fecha
ahogamientos_fecha = ahogamientos_fecha.sort_values(by = ["Anio", "Mes", "Dia"])

ahogamientos_fecha.head()
# Out:
#           Fecha  Dia  Mes  Anio  Ahogamientos
# 1227 2013-01-04    4    1  2013             2
# 1596 2013-01-05    5    1  2013             1
# 1088 2013-01-08    8    1  2013             2
# 1594 2013-01-21   21    1  2013             1
# 1593 2013-01-24   24    1  2013             1

# %%
ahogamientos_fecha.dtypes
# Out:
# Fecha           datetime64[ns]
# Dia                      int64
# Mes                      int64
# Anio                     int64
# Ahogamientos             int64
# dtype: object

# %%
# Visualización serie temportal
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(ahogamientos_fecha, x=ahogamientos_fecha.Fecha, y=ahogamientos_fecha.Ahogamientos, title='Número de ahogamientos por fecha desde 2013 hasta 2020')

# %% [markdown]
# + Se puede observar como hay picos en épocas de verano, es decir, se mantiene un patrón a lo largo del tiempo que suele ser en épocas de verano. Tiene todo el sentido del mundo pensar que el mayor número de ahogamientos ocurren en dichas épocas.

# %% [markdown]
# ## <span style=color:darkblue> Gráfico estacional de una serie temporal </span>

# %%
# Tendencia de los ahogamientos en España por año
def plot_tendencia_ahogamientos(data):
    fig, ax = plt.subplots(figsize=(20, 12))

    for year, group in data.groupby('Anio'):
        group = group.reset_index()
        group['Mes'] = group['Mes'].apply(lambda x: calendar.month_name[x])
        group.plot(x='Mes', y=0, ax=ax, label=str(year))

    ax.set_xlabel('Mes')
    ax.set_ylabel('Nº de ahogamientos')
    ax.set_title('Tendencia de ahogamientos por año')
    ax.legend(title='Año', bbox_to_anchor=(1.02, 1), loc='upper left')

    plt.show()

# %%
# Dividimos los datos por año y mes
ahog_anio_mes = pd.DataFrame(ahogamientos_fecha.groupby(['Anio','Mes']).size())
plot_tendencia_ahogamientos(ahog_anio_mes)

# %% [markdown]
# + Para todos los años, los meses de veranos es donde se producen un mayor número de ahogamientos. Para los primeros años 2013 y 2014 no hay una recopilación de datos tan intensa como en años posteriores pero el patrón es observable para todos los años. Los meses de invierno sueles haber picos descendientes mientras que en verano hay picos ascendentes.

# %% [markdown]
# ## <span style=color:darkblue> Diagrama de caja mensual y anual </span>

# %%
# Dibujamos el plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='Anio', y='Ahogamientos', data=ahogamientos_fecha, ax=axes[0])
sns.boxplot(x='Mes', y='Ahogamientos', data=ahogamientos_fecha.loc[~ahogamientos_fecha.Anio.isin([2013, 2020]), :])

# Fijamos los titulos
axes[0].set_title('Year-wise Box Plot\n(No Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %% [markdown]
# + Se observa analizando el número de ahogamientos por año como no hay una tendencia, de hecho se mantiene muy estable en el tiempo. Por otro lado, si analizamos el número de ahogamientos por meses si que vemos una tendencia en los meses de verano donde el número crece ligeramente respecto al resto de meses que no son verano.

# %% [markdown]
# ## <span style=color:darkblue> Descomposición serie temporal </span>

# %%
# Hacemos una copia de los ahogamientos
ahogamientos_desc = ahogamientos_fecha.copy()

# Ponemos la variable Fecha como indice
ahogamientos_desc.set_index('Fecha', inplace=True)

# Seleccionamos solo las variables Fecha y Ahogamientos
ahogamientos_desc = ahogamientos_desc[['Ahogamientos']]

# %%
# Multiplicative Decomposition
result_mul = seasonal_decompose(ahogamientos_desc['Ahogamientos'], model='multiplicative', period=12)

# Additive Decomposition
result_add = seasonal_decompose(ahogamientos_desc['Ahogamientos'], model='additive', period=12)

# Configuración de los subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

# Definimos los componentes y títulos correspondientes
components = [('observed', 'Observed'), ('trend', 'Trend'), ('seasonal', 'Seasonality'), ('resid', 'Residuals')]

# Generamos los subplots y establecemos los títulos para la descomposición multiplicativa
for col, (component, title) in enumerate(components):
    axes[0, col].plot(getattr(result_mul, component))
    axes[0, col].set_title(f'Multiplicative {title}')

# Generamos los subplots y establecemos los títulos para la descomposición aditiva
for col, (component, title) in enumerate(components):
    axes[1, col].plot(getattr(result_add, component))
    axes[1, col].set_title(f'Additive {title}')

plt.tight_layout()
plt.show()

# %% [markdown]
# + La tendencia y la estacionalidad es muy parecida en ambas descomposiciones donde podemos ver que suele haber una tendencia a lo largo de los meses de verano y una estacionalidad a lo largo de todos los años para las épocas de verano.
#
# + Si nos fijamos en los residuos, la descomposición multiplicativa es bastante aleatoria, lo cual es bueno, ya que la descomposición mantiene un patrón sobrantes en los datos.

# %% [markdown]
# ## <span style=color:darkblue>  Series temporales estacionarias/estacionarias </span>
#
# + La estacionariedad es una propiedad de una serie de tiempo. Una serie estacionaria es aquella en la que los valores de la serie no son una función del tiempo.
#
# + La mayoría de los métodos de pronóstico estadístico están diseñados para trabajar en una serie de tiempo estacionaria. El primer paso en el proceso de pronóstico suele ser hacer alguna transformación para convertir una serie no estacionaria en estacionaria.
#
# ### <span style=color:darkblue>  Probar la estacionalidad </span>
#
# + Usaremos la prueba ADF (Aumented Dickey-Fuller), donde la hipótesis nula es que la serie de tiempo posee raíz unitaria y no es estacionaria. Entonces, si el p-valor en la prueba es menor que el nivel de significación (0.05), rechaza la hipótesis nula.
#
#
# + Usaremos también la prueba KPSS que se utiliza para probar la estacionariedad de la tendencia. La hipótesis nula y la interpretación del valor P es justo lo contrario de la prueba Dickey-Fuller.

# %%
# Prueba Dickey-Fuller
result = adfuller(ahogamientos_desc.Ahogamientos.values, autolag = 'AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
    
# KPSS Test
result = kpss(ahogamientos_desc.Ahogamientos.values, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -4.838045105947319
# p-value: 4.5968738435523345e-05
# Critial Values:
#    1%, -3.4335722342837056
# Critial Values:
#    5%, -2.862963421928457
# Critial Values:
#    10%, -2.567527766920221
#
# KPSS Statistic: 0.564874
# p-value: 0.027056
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739

# %% [markdown]
# + **ADF Statistic:** El valor de -4.838045105947319 es la estadística del test ADF. Si este valor es más negativo que los valores críticos, proporciona evidencia en contra de la hipótesis nula de que la serie temporal no es estacionaria. En este caso, el valor de -4.838045105947319 indica que la serie temporal es probablemente estacionaria.
#
#
# + **p-value ADF:** El valor de p, 4.5968738435523345e-05, es el p-valor asociado al estadístico ADF. Representa la probabilidad de obtener un estadístico ADF tan extremo como el observado si la hipótesis nula fuera verdadera. Un valor de p bajo (generalmente por debajo de un umbral de significancia, como 0.05) indica que la serie temporal es estacionaria. En este caso, el valor extremadamente bajo del p-valor (4.5968738435523345e-05) sugiere que la serie temporal es estacionaria.
#
#
# + **p-value KPSS:** El valor de p, 0.027056, es el p-valor asociado al estadístico KPSS. Representa la probabilidad de obtener un estadístico KPSS tan extremo como el observado si la hipótesis nula (estacionariedad) fuera verdadera. Un valor de p bajo (generalmente por debajo de un umbral de significancia, como 0.05) indica evidencia en contra de la estacionariedad. En este caso, el valor de p (0.027056) es menor que 0.05, lo que sugiere que la serie temporal es no estacionaria.
#
#
# + Los resultados indican que la serie temporal no es completamente estacionaria, ya que el valor del estadístico KPSS es mayor que los valores críticos y el valor de p es menor que 0.05. Esto sugiere que la serie temporal puede tener tendencias o comportamientos no estacionarios.

# %% [markdown]
# ## <span style=color:darkblue>  Modelo SARIMA </span>
#
# + SARIMA (Seasonal Autoregressive Integrated Moving Average), es una clase de modelo que explica una serie de tiempo determinada en función de los valores pasados, es decir, sus proporios retrasos y errores de pronóstico retrasados, por lo que se puede usar para pronosticar valores futuros.
#
#
# + Nuestro modelo presenta estacionalidad, por lo tanto debemos aplicar SARIMA en vez de ARIMA, ya que este último no contempla la estacionalidad.
#
#
# + Un modelo SARIMA se compone de 3 términos:
#
#     + **p** es el orden del término AR
#
#     + **q** es el orden del término MA
#
#     + **d** es el número de diferenciaciones requeridas para hacer que la serie de tiempo sea estacionaria

# %% [markdown]
# ### <span style=color:darkblue>  Diferenciación (d) en el modelo SARIMA </span>
#
# + El orden correcto de diferenciación es la diferenciación mínima requerida para obtener una serie casi estacionaria que se desplaza alrededor de una media definida y la gráfica ACF llega a cero bastante rápido.
#
#
# + Si las autocorrelaciones son positivas para muchos rezagos (10 o más), entonces la serie necesita más diferenciación. Por otro lado, si la autocorrelación del retardo 1 en sí misma es demasiado negativa, es probable que la serie esté sobrediferenciada.

# %%
# Gráfico de autocorrelación 
plt.rcParams.update({'figure.figsize':(8,5), 'figure.dpi':120})
fig, axes = plt.subplots(2, 2)

# Ajustar el espaciado vertical entre subplots
plt.subplots_adjust(hspace=0.5)

# Original Series
axes[0, 0].plot(ahogamientos_desc.Ahogamientos); axes[0, 0].set_title('Original Series')
plot_acf(ahogamientos_desc.Ahogamientos.dropna(), ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(ahogamientos_desc.Ahogamientos.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(ahogamientos_desc.Ahogamientos.diff().dropna(), ax=axes[1, 1])

plt.show()

# %%
# Numero de diferenciaciones según diferentes test
y = ahogamientos_desc.Ahogamientos

## Adf Test
print('ADF Test: ', ndiffs(y, test='adf'))  

# KPSS test
print('KPSS Test: ', ndiffs(y, test='kpss'))

# PP test:
print('PP Test: ', ndiffs(y, test='pp'))
# Out:
# ADF Test:  0
# KPSS Test:  1
# PP Test:  0

# %% [markdown]
# + Podemos observar como a partir del Test de Dickey Fuller realizado anteriormente nos daba que los datos muestran estacionariedad, por lo tanto no es necesario aplicar diferenciación. Vemos como los datos originales tienden rápido a 0 cuando dibujamos el plot de autocorrelaciones sin aplicar órdenes de diferenciación, mientras que si aplicamos una primera diferenciación vemos como el retraso pasa bastante rápido a la zona negativa lejana, lo que indica que la serie podría haber sido sobrediferenciada.
#
# - Nos quedaremos con diferencición d=0.

# %% [markdown]
# ### <span style=color:darkblue>  Autoregresivo (AR) en el modelo SARIMA </span>
#
# + Un modelo autorregresivo puro (solo AR) es aquel en el que Yt depende solo de sus propios retrasos. Es decir, Yt es una función de los 'retrasos de Yt'.
#
#
# + Puede averiguar el número necesario de términos AR inspeccionando el gráfico de autocorrelación parcial (PACF). PACF transmite la correlación pura entre un retraso y la serie. De esa manera, sabrá si ese retraso es necesario en el término AR o no.

# %%
# Encontrar el orden del término AR (p)

# Gráfico de autocorrelación 
plt.rcParams.update({'figure.figsize':(10,3), 'figure.dpi':120})
fig, axes = plt.subplots(1, 2)

# Original Series
axes[0].plot(ahogamientos_desc.Ahogamientos); axes[0].set_title('Original Series')
plot_pacf(ahogamientos_desc.Ahogamientos.dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# + Podemos observar como el PACF lag 1 es bastante significativo, ya que está muy encima de la línea de significación. El lag 2 también resultado significativo al igual que el lag 3 y el lag 4, logrando cruzar ligeramente el límite de significación (región azul). Voy a coger hasta 2 retrasos para ser precavidos.

# %% [markdown]
# ### <span style=color:darkblue>  promedio móvil puro (MA) en el modelo SARIMA </span>
#
# + Un modelo de promedio móvil puro (solo MA) es uno en el que Yt depende solo de los errores de pronóstico retrasados
#
#
# + El ACF indica cuántos términos MA se requieren para eliminar cualquier autocorrelación en la serie estacionaria.

# %%
# Encontrar el orden del término MA (q)

# Gráfico de autocorrelación 
plt.rcParams.update({'figure.figsize':(10,3), 'figure.dpi':120})
fig, axes = plt.subplots(1, 2)

# Original Series
axes[0].plot(ahogamientos_desc.Ahogamientos.values); axes[0].set_title('Original Series')
plot_acf(ahogamientos_desc.Ahogamientos.dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# + El primer retraso está muy por encima de la línea de significación, mientras que el resto de retrasos se mantienen parcialmente fuera no tienen tanta significancia. Por lo tanto fijaremos q = 1. Ante la duda es mejor elegir el modelo más simple que exlique suficientemente la Y.

# %% [markdown]
# ### <span style=color:darkblue>  Construcción del modelo </span>
#
# + El modelo se representará como SARIMA(p,d,q)x(P,D,Q), donde, P, D y Q son términos SAR, orden de diferenciación estacional y SMA respectivamente y es la frecuencia del 'x'tiempo serie.
#
#
# + Si su modelo tiene patrones estacionales bien definidos, aplique D=1 para una frecuencia dada 'x'.
#
#
# + Como regla general, configure los parámetros del modelo de modo que D nunca exceda uno. Y la diferenciación total 'd + D' nunca excede 2. Trate de mantener solo los términos SAR o SMA si su modelo tiene componentes estacionales.

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(ahogamientos_desc[:], label='Original Series')
axes[0].plot(ahogamientos_desc[:].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(ahogamientos_desc[:], label='Original Series')
axes[1].plot(ahogamientos_desc[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %% [markdown]
# + Es invariable que apliquemos diferenciación habitual (log 1) que diferenciación estacional (log 12), ya que los datos son estacionarios y por lo tanto, media y varianza son constantes a lo largo del tiempo, excepto por el hecho que se observa claramente la estacionalidad, debido al gran número de ahogamientos que se produce durante los meses de verano.

# %%
# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(ahogamientos_desc.Ahogamientos, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=1, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=3.09 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=13138.876, Time=0.06 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=11993.808, Time=0.31 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=2.18 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=12600.038, Time=0.10 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=11821.127, Time=0.80 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=5.56 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=1.99 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=12361.413, Time=0.61 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=11554.533, Time=0.93 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=11720.820, Time=0.47 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=9.30 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=4.56 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=11466.860, Time=1.35 sec
# ...

# %% [markdown]
# + Como los datos abarcan todos los meses del año (enero a diciembre) y la estacionalidad se presenta en los meses de junio a septiembre, entonces el valor de 'm' será 12. Esto se debe a que el patrón estacional se repite cada 12 meses, correspondiendo a los meses de verano.
#
# + El mejor modelo tiene un AIC de 11163.238 y los valores de P son significativos.SARIMAX(1, 0, 1)x(2, 1, 0, 12)

# %%
# Gráficos de los residuos en el modelo SARIMA
smodel.plot_diagnostics(figsize= (10,8))
plt.show()

# %% [markdown]
# **Plot1:** los errores residuales parecen fluctuar alrededor de una media de cero y tienen una varianza uniforme.
#
# **Plot2:** el gráfico de densidad sugiere una distribución normal con media cero.
#
# **Plot3:** Todos los puntos deben estar perfectamente alineados con la línea roja. Excepto por la última parte de los puntos que aparece una desviación significativa que implica que la distribución puede estar sesgada.
#
# **Plot4:** Abajo a la derecha: el gráfico Correlogram, también conocido como ACF, muestra que los errores residuales no están autocorrelacionados. Cualquier autocorrelación implicaría que existe algún patrón en los errores residuales que no se explican en el modelo. Por lo tanto, deberá buscar más X (predictores) para el modelo.

# %% [markdown]
# ### <span style=color:darkblue>  Pronóstico </span>

# %% [markdown]
# + Pronóstico de los últimos 24 meses, es decir, el año 2021 y 2022.

# %%
ahogamientos_desc.head()
# Out:
#        Fecha  Ahogamientos
# 0 2013-01-04             2
# 1 2013-01-05             1
# 2 2013-01-08             2
# 3 2013-01-21             1
# 4 2013-01-24             1

# %%
ahogamientos_desc.Fecha.iloc[-1]
# Out:
# Timestamp('2020-12-30 00:00:00')

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(ahogamientos_desc.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted.values, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(ahogamientos_desc.Ahogamientos)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.show()

# %% [markdown]
# # <span style=color:darkblue> Cargando dataset </span>

# %%
# Guardar el DataFrame como archivo CSV
ahogamientos_fecha.to_csv('ahogamientos_fecha.csv', index=False)

# %%
# Cargamos los datos
df = pd.read_csv('ahogamientos_fecha.csv', index_col= 'Fecha', parse_dates= True)
df
# Out:
#             Dia  Mes  Anio  Ahogamientos
# Fecha
# 2013-01-04    4    1  2013             2
# 2013-01-05    5    1  2013             1
# 2013-01-08    8    1  2013             2
# 2013-01-21   21    1  2013             1
# 2013-01-24   24    1  2013             1
# ...         ...  ...   ...           ...
# 2020-12-24   24   12  2020             4
# 2020-12-25   25   12  2020             1
# 2020-12-28   28   12  2020             5
# 2020-12-29   29   12  2020             3
# 2020-12-30   30   12  2020             1
#
# [2046 rows x 4 columns]

# %%
train = df.iloc[:1761, :]
test = df.iloc[1761:, :]

# %%
model = pm.auto_arima(y = train.Ahogamientos, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=1, D=1, trace=False,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

# %%
predictions = pd.Series(model.predict(n_periods= len(test)))
predictions.index = test.index
predictions[:5]
# Out:
# /Users/adrianova/mambaforge/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/adrianova/mambaforge/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Fecha
# 2020-01-01    5.447896
# 2020-01-02    3.186428
# 2020-01-03    4.672557
# 2020-01-04    3.476150
# 2020-01-05    6.093422
# dtype: float64

# %%
train.Ahogamientos['2019-01-01':].plot(figsize = (12,8), legend = True)
test.Ahogamientos.plot(figsize = (12,8), legend = True)
predictions.plot(legend = True)
# Out:
# <Axes: xlabel='Fecha'>

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                 1761
# Model:             SARIMAX(0, 1, 1)x(2, 1, [], 12)   Log Likelihood               -4743.255
# Date:                             Sun, 02 Jul 2023   AIC                           9494.510
# Time:                                     10:52:27   BIC                           9516.375
# Sample:                                          0   HQIC                          9502.593
#                                             - 1761
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8914      0.010    -90.866      0.000      -0.911      -0.872
# ...

# %%
df.Ahogamientos
# Out:
# Fecha
# 2013-01-04    2
# 2013-01-05    1
# 2013-01-08    2
# 2013-01-21    1
# 2013-01-24    1
#              ..
# 2020-12-24    4
# 2020-12-25    1
# 2020-12-28    5
# 2020-12-29    3
# 2020-12-30    1
# Name: Ahogamientos, Length: 2046, dtype: int64

# %%
# Forecast
n_periods = 24
fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(df.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted.values, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(df.Ahogamientos['2020-09-01':].dropna())
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.show()
# Out:
# /Users/adrianova/mambaforge/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/adrianova/mambaforge/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
